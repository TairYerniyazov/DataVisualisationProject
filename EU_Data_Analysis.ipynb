# %% [markdown]
# #**Wstęp**
#
#
# ---
#
# > **Temat:** Zbiorcza wizualizacja ogólnych danych dotyczących jakości życia w krajach UE.
# <br>
# > **Dane:** Eurostat, UNICEF Data Warehouse, World Bank.
# <br>
# > **Biblioteki**: [geo]pandas, plotly, matplotlib, BeautifulSoup.
# <br>
# > **Języki programowania**: Python, PostScript.
# <br>
#
# ---

# %% [markdown]
# ## **Temat 1: Długość życia na mapie**
# https://colab.research.google.com/drive/1uVN7dESByHFCi02b4HdVXSvPdnQv_kGL?usp=sharing
#
# <p><span style="font-family:Times New Roman,Times,serif"><span style="color:#2980b9"><img alt="" src="" width=400/></span></span></p>
#
# ---

# %% [markdown]
# ## **Temat 2: Emisja dwutlenku węgla**
# https://colab.research.google.com/drive/16lkXP-u5XzxXlSQB6qxN4310_1-rTKpA?usp=sharing
#
# <br>
#
# ---

# %% [markdown]
# ## **Temat 3: Średnie wynagrodzenie**
# https://colab.research.google.com/drive/1vtCNGldAm266HBtSUG9U94gINvAIjDDx?usp=sharing
#
# <br>
#
# ---

# %% [markdown]
# ## **Temat 4: Stopa bezrobocia**
#  https://colab.research.google.com/drive/1nFTTMnZU8NkoGjbPyydR5R9q_UDHXz-6?usp=sharing
#
# <br>
#
# ---

# %% [markdown]
# #**Podsumowanie**
#
#
# ---
# *  Oczekiwana długość życia ciągle rosła od 2003 do 2019 r., czyli rozpoczęła się pandemia COVID-19.
# *  Nie ma korelacji pomiędzy długością życia a emisją dwutlenku węgla. Możemy spekulować, że CO2 nie wpływa na zdrowie mieszkańców emitującego kraju, zaś skutki są widoczne w innych krajach.
# <br><br>
# * Wzrost emisji CO2 we wszystkich krajach od roku 1950 do 1980. Każdy region jednak charakteryzuje się innym zachowaniem.
# * Wysokość wynagrodzenia niekoniecznie wpływa na długość życia.
# <br><br>
# * Biorąc pod uwagę lata z pełnym zestawem danych (2010-2020), w roku 2013 suma stóp bezrobocia w krajach UE była największa.
# * Przeważnie nie ma zależności między między stopą bezrobocia a porą roku. Wyjątkami są Islandia oraz Finlandia.
# * W 2014 roku średnia stopa bezrobocia kobiet w UE była równa stopie bezrobocia mężczyzn. Największą różnica była w roku 1986 i wynosiła ponad 4 punkty procentowe.
# * Na przestrzeni 40 lat jedynie w latach 2009-2013 stopa bezrobocia średniego u mężczyzn w krajach UE przewyższała stopę bezrobocia kobiet.
#
#
# ---

# %% [markdown]
# 2023 © Daniel Broś, Piotr Wojcieszak, Tair Yerniyazov.
# <br>
#
#
# ---
